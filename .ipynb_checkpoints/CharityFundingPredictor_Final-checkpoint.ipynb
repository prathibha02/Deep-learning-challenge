# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("sample_data/charity_data.csv")
application_df
# Out:
#              EIN                                               NAME  \
# 0       10520599                       BLUE KNIGHTS MOTORCYCLE CLUB
# 1       10531628             AMERICAN CHESAPEAKE CLUB CHARITABLE TR
# 2       10547893                 ST CLOUD PROFESSIONAL FIREFIGHTERS
# 3       10553066                     SOUTHSIDE ATHLETIC ASSOCIATION
# 4       10556103           GENETIC RESEARCH INSTITUTE OF THE DESERT
# ...          ...                                                ...
# 34294  996009318              THE LIONS CLUB OF HONOLULU KAMEHAMEHA
# 34295  996010315           INTERNATIONAL ASSOCIATION OF LIONS CLUBS
# 34296  996012607                                PTA HAWAII CONGRESS
# 34297  996015768  AMERICAN FEDERATION OF GOVERNMENT EMPLOYEES LO...
# 34298  996086871                           WATERHOUSE CHARITABLE TR
#
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0                  T10       Independent          C1000    ProductDev
# ...

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(["EIN", "NAME"], axis=1)
application_df
# Out:
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0                  T10       Independent          C1000    ProductDev
# 1                   T3       Independent          C2000  Preservation
# 2                   T5  CompanySponsored          C3000    ProductDev
# 3                   T3  CompanySponsored          C2000  Preservation
# 4                   T3       Independent          C1000     Heathcare
# ...                ...               ...            ...           ...
# 34294               T4       Independent          C1000    ProductDev
# 34295               T4  CompanySponsored          C3000    ProductDev
# 34296               T3  CompanySponsored          C2000  Preservation
# 34297               T5       Independent          C3000    ProductDev
# 34298               T3       Independent          C1000  Preservation
#
#        ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS   ASK_AMT  \
# ...

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
application_counts = application_df["APPLICATION_TYPE"].value_counts()
application_counts
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = list(application_counts[application_counts<100].index)
application_types_to_replace   

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")
application_df
# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# T9         156
# Other      120
# Name: APPLICATION_TYPE, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
class_counts = application_df["CLASSIFICATION"].value_counts()
class_counts[class_counts>1]
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = list(class_counts[class_counts<1000].index)

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
applicationWithDUmmies_df = pd.get_dummies(application_df)
applicationWithDUmmies_df
# Out:
#        STATUS   ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0           1      5000              1                       0
# 1           1    108590              1                       0
# 2           1      5000              0                       0
# 3           1      6692              1                       0
# 4           1    142590              1                       0
# ...       ...       ...            ...                     ...
# 34294       1      5000              0                       0
# 34295       1      5000              0                       0
# 34296       1      5000              0                       0
# 34297       1      5000              1                       0
# 34298       1  36500179              0                       0
#
#        APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  \
# 0                         1                     0                    0
# ...

# %%
# Split our preprocessed data into our features and target arrays
X = applicationWithDUmmies_df.drop(["IS_SUCCESSFUL"], axis='columns').values
y = applicationWithDUmmies_df["IS_SUCCESSFUL"].values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=42)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
numberInputFeatures = len(X_train[0])
hiddenNodesL1 = 500
hiddenNodesL2 = 500
hiddenNodesL3 = 100
hiddenNodesL4 = 50
#hiddenNodesL5 = 100
# hiddenNodesL6 = 100

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hiddenNodesL1, input_dim=numberInputFeatures, activation="relu"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hiddenNodesL2, activation="relu"))

# Third hidden layer
nn.add(tf.keras.layers.Dense(units=hiddenNodesL3, activation="relu"))

# Fourth hidden layer
nn.add(tf.keras.layers.Dense(units=hiddenNodesL4, activation="relu"))

# Fifth hidden layer
# nn.add(tf.keras.layers.Dense(units=hiddenNodesL5, activation="relu"))

# Sixth hidden layer
# nn.add(tf.keras.layers.Dense(units=hiddenNodesL6, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_13 (Dense)            (None, 500)               22500
#
#  dense_14 (Dense)            (None, 500)               250500
#
#  dense_15 (Dense)            (None, 100)               50100
#
#  dense_16 (Dense)            (None, 50)                5050
#
#  dense_17 (Dense)            (None, 1)                 51
#
# ...
# Total params: 328,201
# Trainable params: 328,201
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=100,verbose=2)
# Out:
# Epoch 1/100
# 804/804 - 3s - loss: 0.5699 - accuracy: 0.7210 - 3s/epoch - 4ms/step
# Epoch 2/100
# 804/804 - 3s - loss: 0.5568 - accuracy: 0.7306 - 3s/epoch - 3ms/step
# Epoch 3/100
# 804/804 - 3s - loss: 0.5544 - accuracy: 0.7295 - 3s/epoch - 3ms/step
# Epoch 4/100
# 804/804 - 3s - loss: 0.5524 - accuracy: 0.7293 - 3s/epoch - 3ms/step
# Epoch 5/100
# 804/804 - 3s - loss: 0.5503 - accuracy: 0.7306 - 3s/epoch - 4ms/step
# Epoch 6/100
# 804/804 - 3s - loss: 0.5504 - accuracy: 0.7310 - 3s/epoch - 4ms/step
# Epoch 7/100
# 804/804 - 3s - loss: 0.5485 - accuracy: 0.7331 - 3s/epoch - 3ms/step
# Epoch 8/100
# 804/804 - 3s - loss: 0.5468 - accuracy: 0.7331 - 3s/epoch - 3ms/step
# Epoch 9/100
# 804/804 - 2s - loss: 0.5465 - accuracy: 0.7337 - 2s/epoch - 3ms/step
# Epoch 10/100
# 804/804 - 2s - loss: 0.5456 - accuracy: 0.7335 - 2s/epoch - 3ms/step
# Epoch 11/100
# 804/804 - 3s - loss: 0.5460 - accuracy: 0.7342 - 3s/epoch - 3ms/step
# Epoch 12/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.6094 - accuracy: 0.7301 - 468ms/epoch - 2ms/step
# Loss: 0.6094393134117126, Accuracy: 0.7301457524299622

# %%
# Export our model to HDF5 file
nn.save("AlphabetSoupCharity_Optimzation2.h5")

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# # Analysis

# %% [markdown]
# ### Data Preprocessing:
# * The Target of the Model was IS_SUCCESSFUL
# * The Features of the Model was APPLICATION_TYPE, CLASSIFICATION
# Based on the Application Type and Classification, we tried to predict whther the Charity Funding was successful or Not
#
# * The variables EIN number and Name were deleted because they were not relevent in building or usng the model

# %% [markdown]
# ### Compiling, Training, and Evaluating the Model
# * After many trial runs, 4 layers were chosen. For level 1,2,3 100 nuerons were selected and on the 4th layer, 50 neurons were chosen. The activation funtion that was used was ReLU (Rectified Linear Unit), a part of Convolutional Neural Networks (CNNs).
# * The target was 75% Accuracy but we could achieve only 73.014% Accuracy
# * By adding and taking away layers and the number of neurons, we found that maximum accuracy occured with 4 layers and 350 neurons

# %% [markdown]
# ### Summary
# The overall accuracy of the model was 73% and the loss was 60.94% The performance of the model was wasn't too good.
# I would recommend Multilayer Perceptrons (MLPs) as the best deep learning algorithm. It can speed up the run time of the model and improve the accuracy.
